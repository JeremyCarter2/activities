# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# prepare data
gasPrices = pd.read_csv('/Users/jeremycarter/Code/SavvyCoders/activities/gas_price_by_state.csv')
# print(gasprices)

labels = gasPrices['name']
values = gasPrices['gasoline']

plt.figure(figsize=(15, 7))
plt.xticks(rotation=90)
plt.ylim(2, 6)
plt.title('Gas Prices per State')
plt.xlabel('State')
plt.ylabel('Gasoline Price')

gasBar = plt.bar(labels, values)

# %% [markdown]
# This is review of webscraping

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as soup

url = "http://www.usa.com/rank/us--average-temperature--state-rank.htm"
data = requests.get(url).text

temps=soup(data, "html.parser")

table=temps.find_all('table')
table=temps.find('table',width='648')

rank = []
averagetemp = []
statepopulation = []

for row in table.find_all('tr'):
    columns = row.find_all('td')
    rank.append(columns[0].text.strip())
    averagetemp.append(columns[1].text.strip())
    statepopulation.append(columns[2].text.strip())

r=pd.DataFrame(rank)
a=pd.DataFrame(averagetemp)
s=pd.DataFrame(statepopulation)

df=pd.concat([r,a,s], axis=1)

df.columns=df.iloc[0]
df=df.drop([0])

df=df.sort_values(by=['State / Population'])

df.to_csv('AvgTempsByState.csv')



df
# Out:
# 0  Rank Average Temperature ▼              State / Population
# 7    7.               62.68°F             Alabama / 4,817,678
# 51  51.               32.03°F                Alaska / 728,300
# 4    4.               65.97°F             Arizona / 6,561,516
# 12  12.               60.09°F            Arkansas / 2,947,036
# 10  10.               61.17°F         California / 38,066,920
# 41  41.               46.26°F            Colorado / 5,197,580
# 35  35.               48.60°F         Connecticut / 3,592,053
# 22  22.               54.48°F              Delaware / 917,060
# 18  18.               54.73°F  District of Columbia / 633,736
# 2    2.               71.80°F            Florida / 19,361,792
# 8    8.               62.30°F             Georgia / 9,907,756
# 1    1.               72.95°F              Hawaii / 1,392,704
# 40  40.               46.32°F               Idaho / 1,599,464
# 27  27.               51.37°F           Illinois / 12,868,747
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as soup

open('/Users/jeremycarter/Code/SavvyCoders/activities/ClassProject/EVRegistrations.xlsx')
file1=pd.read_excel('/Users/jeremycarter/Code/SavvyCoders/activities/ClassProject/EVRegistrations.xlsx')
file1=file1.drop(file1.index[44:45])
file1=file1.drop('Unnamed: 7', axis=1)
file1=file1.drop('Unnamed: 8', axis=1)
file1=file1.drop('Unnamed: 9', axis=1)
file1=file1.drop('Unnamed: 10', axis=1)
file1=file1.drop('Unnamed: 11', axis=1)

file1.to_csv('evreg.csv')

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as soup

file1=pd.read_csv('/Users/jeremycarter/Code/SavvyCoders/activities/AvgTempsByState.csv')
file2=pd.read_csv('/Users/jeremycarter/Code/SavvyCoders/activities/evreg.csv')
# file3=pd.read_csv()

df1=pd.concat([file1,file2],axis=1)
df1.to_csv('DataFrame.csv')
